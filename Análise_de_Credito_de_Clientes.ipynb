# %% [markdown]
# <a href="https://colab.research.google.com/github/Fecarvalho00/Analise_de_Risco_de_Credito/blob/main/An%C3%A1lise_de_Credito_de_Clientes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Projetos DS/Risco de credito/credit_customers.csv')
df.head(10)
# Out:
#   checking_status  duration                  credit_history  \
# 0              <0       6.0  critical/other existing credit
# 1        0<=X<200      48.0                   existing paid
# 2     no checking      12.0  critical/other existing credit
# 3              <0      42.0                   existing paid
# 4              <0      24.0              delayed previously
# 5     no checking      36.0                   existing paid
# 6     no checking      24.0                   existing paid
# 7        0<=X<200      36.0                   existing paid
# 8     no checking      12.0                   existing paid
# 9        0<=X<200      30.0  critical/other existing credit
#
#                purpose  credit_amount    savings_status  employment  \
# 0             radio/tv         1169.0  no known savings         >=7
# 1             radio/tv         5951.0              <100      1<=X<4
# 2            education         2096.0              <100      4<=X<7
# ...

# %%
df.dtypes

# %% [markdown]
# ## Pré-processamento dos dados
